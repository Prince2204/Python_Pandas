# %% [markdown]
# # Plotting

# %% [markdown]
# Pandas uses the plot() method to create diagrams.
#
# We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.

# %%
#Load the csv into a dataframe

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\prinfnu\\Documents\\Python Scripts\\Python_Exercies_Jupyter_Notebook\\data.csv')

df.plot()

plt.show()
# Out:
# C:\Users\prinfnu\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# # Scatterplot

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\prinfnu\\Documents\\Python Scripts\\Python_Exercies_Jupyter_Notebook\\data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Pulse')

plt.show()
# Out:
# C:\Users\prinfnu\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\prinfnu\\Documents\\Python Scripts\\Python_Exercies_Jupyter_Notebook\\data.csv')

df["Pulse"].plot(kind = 'hist')

plt.show()
# Out:
# C:\Users\prinfnu\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
